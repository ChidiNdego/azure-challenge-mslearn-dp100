# %% [markdown]
# # Create a Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this notebook, you'll bring together all of these elements to create a simple pipeline that pre-processes data and then trains and registers a model.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.22.0 to work with azure_ds_challenge

# %% [markdown]
# ## Prepare data
#
# In your pipeline, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it in previously, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like a data transfer step that copies data from one location to another. Each step can run in its own compute context. In this exercise, you'll build a simple pipeline that contains two Python script steps: one to pre-process some training data, and another to use the pre-processed data to train and register a model.
#
# First, let's create a folder for the script files we'll use in the pipeline steps.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now let's create the first script, which will read data from the diabetes dataset and apply some simple pre-processing to remove any rows with missing data and normalize the numeric features so they're on a similar scale.
#
# The script includes a argument named **--prepped-data**, which references the folder where the resulting data should be saved.

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Writing diabetes_pipeline/prep_diabetes.py

# %% [markdown]
# Now you can create the script for the second step, which will train a model. The script includes a argument named **--training-folder**, which references the folder where the prepared data was saved by the previous step.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Overwriting diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "azure-compute"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Creating
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so you'll need to create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to be passed between them. In this case, the first step must write the prepared data to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so our code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [b56f6bca][024b2a54-be73-4ca1-a12a-f013c1e1e61f], (This step will run and generate new outputs)
# Created step Train and Register Model [8196ca8d][ba35d0db-be3b-4f08-807d-56727ab1aa0a], (This step will run and generate new outputs)
# Submitted PipelineRun 12849b14-2b76-4c57-a609-c605d5e8a9f3
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/12849b14-2b76-4c57-a609-c605d5e8a9f3?wsid=/subscriptions/cdb9c206-0977-4fc2-9190-23ed6c7c7063/resourcegroups/stanbic/workspaces/azure_ds_challenge
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 12849b14-2b76-4c57-a609-c605d5e8a9f3
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/12849b14-2b76-4c57-a609-c605d5e8a9f3?wsid=/subscriptions/cdb9c206-0977-4fc2-9190-23ed6c7c7063/resourcegroups/stanbic/workspaces/azure_ds_challenge
# PipelineRun Status: Running
#
#
# StepRunId: 660aadd3-a519-44d2-8a9f-c65406043a61
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/660aadd3-a519-44d2-8a9f-c65406043a61?wsid=/subscriptions/cdb9c206-0977-4fc2-9190-23ed6c7c7063/resourcegroups/stanbic/workspaces/azure_ds_challenge
# StepRun( Prepare Data ) Status: NotStarted
# StepRun( Prepare Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/03/25 20:52:15 Downloading source code...
# 2021/03/25 20:52:16 Finished downloading source code
# 2021/03/25 20:52:17 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/03/25 20:52:17 Successfully set up Docker network: acb_default_network
# 2021/03/25 20:52:17 Setting up Docker configuration...
# 2021/03/25 20:52:18 Successfully set up Docker configuration
# 2021/03/25 20:52:18 Logging in to registry: 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io
# 2021/03/25 20:52:19 Successfully logged into 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io
# 2021/03/25 20:52:19 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/25 20:52:19 Scanning for dependencies...
# 2021/03/25 20:52:20 Successfully scanned dependencies
# 2021/03/25 20:52:20 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/18 : USER root
#  ---> Running in cb31dedc7f25
# Removing intermediate container cb31dedc7f25
#  ---> e6ea36686fb8
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in c3e57e262986
# Removing intermediate container c3e57e262986
#  ---> 92cbbc78df80
# Step 4/18 : WORKDIR /
#  ---> Running in 437c5b0ca755
# Removing intermediate container 437c5b0ca755
#  ---> 9cecd9434a4e
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> b4c2b9d6717e
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 874d21123443
# Removing intermediate container 874d21123443
#  ---> ada4b3a1c244
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> d3a84887b41f
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 9e00b71745e0
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | 3          |   4%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 6          |   6%
# mkl-2019.4           | 204.1 MB  | #          |  10%
# mkl-2019.4           | 204.1 MB  | #4         |  14%
# mkl-2019.4           | 204.1 MB  | #8         |  18%
# mkl-2019.4           | 204.1 MB  | ##2        |  23%
# mkl-2019.4           | 204.1 MB  | ##7        |  27%
# mkl-2019.4           | 204.1 MB  | ###1       |  31%
# mkl-2019.4           | 204.1 MB  | ###5       |  35%
# mkl-2019.4           | 204.1 MB  | ####       |  41%
# mkl-2019.4           | 204.1 MB  | ####5      |  45%
# mkl-2019.4           | 204.1 MB  | #####      |  50%
# mkl-2019.4           | 204.1 MB  | #####4     |  55%
# mkl-2019.4           | 204.1 MB  | #####9     |  59%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######7    |  67%
# mkl-2019.4           | 204.1 MB  | #######1   |  72%
# mkl-2019.4           | 204.1 MB  | #######6   |  77%
# mkl-2019.4           | 204.1 MB  | ########1  |  81%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | ########5  |  85%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | #8         |  19%
# pandas-1.1.3         | 10.5 MB   | ########4  |  84%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ####1      |  42%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ######3    |  63%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | #######    |  71%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ######4    |  64%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##6        |  27%
# python-3.6.2         | 27.0 MB   | #####7     |  57%
# python-3.6.2         | 27.0 MB   | ########9  |  89%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #########9 |  99%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | ##3        |  23%
# icu-58.2             | 22.7 MB   | ######4    |  64%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ###6       |  36%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 6          |   7%
# qt-5.9.6             | 86.7 MB   | #7         |  17%
# qt-5.9.6             | 86.7 MB   | ##8        |  29%
# qt-5.9.6             | 86.7 MB   | ###5       |  36%
# qt-5.9.6             | 86.7 MB   | ####5      |  46%
# qt-5.9.6             | 86.7 MB   | #####7     |  57%
# qt-5.9.6             | 86.7 MB   | ######8    |  68%
# qt-5.9.6             | 86.7 MB   | #######9   |  79%
# qt-5.9.6             | 86.7 MB   | #########1 |  91%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ####7      |  48%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ###7       |  37%
# scipy-1.5.2          | 18.5 MB   | ######5    |  65%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | #####4     |  55%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.9cmfmk80.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.22.0
#   Downloading azureml_defaults-1.22.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.13.0-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.22.0
#   Downloading azureml_dataset_runtime-1.22.0-py3-none-any.whl (3.4 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-core~=1.22.0
#   Downloading azureml_core-1.22.0-py3-none-any.whl (2.1 MB)
# Collecting azureml-dataprep-native<33.0.0,>=32.0.0
#   Downloading azureml_dataprep_native-32.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-rslex<1.12.0a,>=1.11.0dev0
#   Downloading azureml_dataprep_rslex-1.11.0-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.9cmfmk80.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.9cmfmk80.requirements.txt (line 2)) (1.1.3)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv.9cmfmk80.requirements.txt (line 1)) (2020.1)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.3 in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv.9cmfmk80.requirements.txt (line 1)) (2.8.1)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv.9cmfmk80.requirements.txt (line 1)) (1.15.0)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting docker
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.13-py2.py3-none-any.whl (111 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.10.0-py2.py3-none-any.whl (60 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.12.0-py2.py3-none-any.whl (130 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib/python3.6/site-packages (from requests>=2.17.3->azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.22.0->-r /azureml-environment-setup/condaenv.9cmfmk80.requirements.txt (line 1)) (2020.6.20)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.58.0-py2.py3-none-any.whl (61 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.7.3-py3-none-any.whl (12 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=5c26d76541b0adb7112ce81683d8260cc392d9ab32272500f18687386df0fdac
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=eb89e03668aab617b93e2f2eeb4d8a214f1bb779b70fbf4f271d01d084c6ad45
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=bedeebb66758092384fbeb8df9ad905b245c3c00a00aa9fe6a231f23083d28d4
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: gunicorn, json-logging-py, applicationinsights, configparser, pyarrow, azureml-dataprep-native, distro, dotnetcore2, cloudpickle, azureml-dataprep-rslex, pycparser, cffi, cryptography, PyJWT, chardet, urllib3, idna, requests, msal, azure-core, portalocker, msal-extensions, azure-identity, azureml-dataprep, fusepy, azureml-dataset-runtime, werkzeug, liac-arff, dill, adal, azureml-model-management-sdk, click, itsdangerous, MarkupSafe, Jinja2, flask, jmespath, pyasn1, pyopenssl, ndg-httpsclient, websocket-client, docker, azure-common, oauthlib, requests-oauthlib, isodate, msrest, jeepney, SecretStorage, typing-extensions, zipp, importlib-metadata, jsonpickle, ruamel.yaml.clib, ruamel.yaml, msrestazure, azure-mgmt-keyvault, pathspec, backports.weakref, backports.tempfile, azure-mgmt-authorization, azure-graphrbac, azure-mgmt-containerregistry, contextlib2, azure-mgmt-resource, azure-mgmt-storage, azureml-core, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-2.0.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.12.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-core-1.22.0 azureml-dataprep-2.13.0 azureml-dataprep-native-32.0.0 azureml-dataprep-rslex-1.11.0 azureml-dataset-runtime-1.22.0 azureml-defaults-1.22.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.7.3 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.10.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.13 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.4 websocket-client-0.58.0 werkzeug-1.0.1 zipp-3.4.1
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 9e00b71745e0
#  ---> b2b1827408ad
# Step 9/18 : ENV PATH /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin:$PATH
#  ---> Running in 06fc1f5f55aa
# Removing intermediate container 06fc1f5f55aa
#  ---> 79e8937bd99d
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 502466dfecdb
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 6b6b5d151c92
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d
#  ---> Running in 19c95924f12a
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 19c95924f12a
#  ---> 5d152d6be204
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d
#  ---> Running in da959b3e2746
# Removing intermediate container da959b3e2746
#  ---> c36309daf532
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/lib:$LD_LIBRARY_PATH
#  ---> Running in 72cf715ed6f8
# Removing intermediate container 72cf715ed6f8
#  ---> 72b58e22c69c
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> b80cf7e52893
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 8be5ad089817
# Removing intermediate container 8be5ad089817
#  ---> 7831b5147102
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in ecbdb05a5d17
# Removing intermediate container ecbdb05a5d17
#  ---> 33a79a92d5e4
# Step 18/18 : CMD ["bash"]
#  ---> Running in ba018b8a52ef
# Removing intermediate container ba018b8a52ef
#  ---> 3a8409d59b7b
# Successfully built 3a8409d59b7b
# Successfully tagged 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:latest
# Successfully tagged 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:1
# 2021/03/25 20:58:03 Successfully executed container: acb_step_0
# 2021/03/25 20:58:03 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/25 20:58:03 Pushing image: 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:1, attempt 1
# The push refers to repository [45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598]
# 92c92688b664: Preparing
# 75331cb0eead: Preparing
# b244eb52d606: Preparing
# a57bcc20cc99: Preparing
# f6d27e1e27e2: Preparing
# 83a373e749c6: Preparing
# 95645b28b5f8: Preparing
# 17a4d7926037: Preparing
# 7670a22d1847: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 83a373e749c6: Waiting
# 95645b28b5f8: Waiting
# 17a4d7926037: Waiting
# 7670a22d1847: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# da2785b7bb16: Waiting
# 0c7d6f1219f0: Waiting
# 75331cb0eead: Pushed
# 92c92688b664: Pushed
# b244eb52d606: Pushed
# a57bcc20cc99: Pushed
# 83a373e749c6: Pushed
# 95645b28b5f8: Pushed
# 17a4d7926037: Pushed
# f449d8429d6e: Pushed
# 7670a22d1847: Pushed
# c9fd473f5354: Pushed
# cbb89d0b53de: Pushed
# fc2b9863058f: Pushed
# 088c5f014be3: Pushed
# 1a1a19626b20: Pushed
# 0c7d6f1219f0: Pushed
# e342e7653d41: Pushed
# 5b7dc8292d9b: Pushed
# bbc674332e2e: Pushed
# da2785b7bb16: Pushed
# 8547178b7afb: Pushed
#
# f6d27e1e27e2: Pushed
# 1: digest: sha256:d7c33783a36f782fe75cc9cb93661019588846af0bfdbf60310f0d0b2286e490 size: 4721
# 2021/03/25 21:01:04 Successfully pushed image: 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:1
# 2021/03/25 21:01:04 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/25 21:01:04 Pushing image: 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:latest, attempt 1
# The push refers to repository [45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598]
# 92c92688b664: Preparing
# 75331cb0eead: Preparing
# b244eb52d606: Preparing
# a57bcc20cc99: Preparing
# f6d27e1e27e2: Preparing
# 83a373e749c6: Preparing
# 95645b28b5f8: Preparing
# 17a4d7926037: Preparing
# 7670a22d1847: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 83a373e749c6: Waiting
# 95645b28b5f8: Waiting
# e342e7653d41: Waiting
# 17a4d7926037: Waiting
# fc2b9863058f: Waiting
# 7670a22d1847: Waiting
# 8547178b7afb: Waiting
# c9fd473f5354: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# bbc674332e2e: Waiting
# 088c5f014be3: Waiting
# da2785b7bb16: Waiting
# 0c7d6f1219f0: Waiting
# b244eb52d606: Layer already exists
# f6d27e1e27e2: Layer already exists
# 75331cb0eead: Layer already exists
# a57bcc20cc99: Layer already exists
# 92c92688b664: Layer already exists
# c9fd473f5354: Layer already exists
# 7670a22d1847: Layer already exists
# 17a4d7926037: Layer already exists
# f449d8429d6e: Layer already exists
# 088c5f014be3: Layer already exists
# cbb89d0b53de: Layer already exists
# 0c7d6f1219f0: Layer already exists
# 83a373e749c6: Layer already exists
# 95645b28b5f8: Layer already exists
# 8547178b7afb: Layer already exists
# 1a1a19626b20: Layer already exists
# 5b7dc8292d9b: Layer already exists
# bbc674332e2e: Layer already exists
# da2785b7bb16: Layer already exists
# fc2b9863058f: Layer already exists
# e342e7653d41: Layer already exists
# latest: digest: sha256:d7c33783a36f782fe75cc9cb93661019588846af0bfdbf60310f0d0b2286e490 size: 4721
# 2021/03/25 21:01:11 Successfully pushed image: 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:latest
# 2021/03/25 21:01:11 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 343.840284)
# 2021/03/25 21:01:11 Populating digests for step ID: acb_step_0...
# 2021/03/25 21:01:15 Successfully populated digests for step ID: acb_step_0
# 2021/03/25 21:01:15 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 180.792302)
# 2021/03/25 21:01:15 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 7.098709)
# 2021/03/25 21:01:15 The following dependencies were found:
# 2021/03/25 21:01:15
# - image:
#     registry: 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io
#     repository: azureml/azureml_a3f083b546e87f8223915308da5ad598
#     tag: latest
#     digest: sha256:d7c33783a36f782fe75cc9cb93661019588846af0bfdbf60310f0d0b2286e490
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
# - image:
#     registry: 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io
#     repository: azureml/azureml_a3f083b546e87f8223915308da5ad598
#     tag: "1"
#     digest: sha256:d7c33783a36f782fe75cc9cb93661019588846af0bfdbf60310f0d0b2286e490
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
# Run ID: ch2 was successful after 9m1s
# Streaming azureml-logs/55_azureml-execution-tvmps_579d96b9128ed68ee9a6c995d54cbdb3636f100cf7f6164381a55108db23da7a_d.txt
# ========================================================================================================================
# 2021-03-25T21:04:46Z Starting output-watcher...
# 2021-03-25T21:04:46Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-03-25T21:04:47Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-03-25T21:04:47Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_a3f083b546e87f8223915308da5ad598
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# c1cd5f0482c9: Pulling fs layer
# 1a03b31305c4: Pulling fs layer
# 1a15a8e4be9b: Pulling fs layer
# 279e7fc2baf6: Pulling fs layer
# 4f2aefeff58b: Pulling fs layer
# 5c6bee030496: Pulling fs layer
# 54ec1c096898: Pulling fs layer
# 4e9ce0bb5e97: Pulling fs layer
# 6675980ac333: Pulling fs layer
# d54d011de0e3: Waiting
# c1cd5f0482c9: Waiting
# 1a03b31305c4: Waiting
# 1a15a8e4be9b: Waiting
# 279e7fc2baf6: Waiting
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# 4f2aefeff58b: Waiting
# 5c6bee030496: Waiting
# 54ec1c096898: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# 4e9ce0bb5e97: Waiting
# c445dda55407: Waiting
# 6675980ac333: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 1a03b31305c4: Verifying Checksum
# 1a03b31305c4: Download complete
# 1a15a8e4be9b: Verifying Checksum
# 1a15a8e4be9b: Download complete
# 279e7fc2baf6: Verifying Checksum
# 279e7fc2baf6: Download complete
# c1cd5f0482c9: Verifying Checksum
# c1cd5f0482c9: Download complete
# 5c6bee030496: Verifying Checksum
# 5c6bee030496: Download complete
# 54ec1c096898: Verifying Checksum
# 54ec1c096898: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# 6675980ac333: Verifying Checksum
# 6675980ac333: Download complete
# 4e9ce0bb5e97: Verifying Checksum
# 4e9ce0bb5e97: Download complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# 4f2aefeff58b: Verifying Checksum
# 4f2aefeff58b: Download complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# c1cd5f0482c9: Pull complete
# 1a03b31305c4: Pull complete
# 1a15a8e4be9b: Pull complete
# 279e7fc2baf6: Pull complete
# 4f2aefeff58b: Pull complete
# 5c6bee030496: Pull complete
# 54ec1c096898: Pull complete
# 4e9ce0bb5e97: Pull complete
# 6675980ac333: Pull complete
# Digest: sha256:d7c33783a36f782fe75cc9cb93661019588846af0bfdbf60310f0d0b2286e490
# Status: Downloaded newer image for 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:latest
# 45d7f8c8c5ec4f4f93ccd3f6a3356189.azurecr.io/azureml/azureml_a3f083b546e87f8223915308da5ad598:latest
# 2021-03-25T21:05:51Z Check if container 660aadd3-a519-44d2-8a9f-c65406043a61 already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_579d96b9128ed68ee9a6c995d54cbdb3636f100cf7f6164381a55108db23da7a_d.txt
# ===============================================================================================================
# [2021-03-25T21:06:13.526679] Entering job preparation.
# [2021-03-25T21:06:15.469660] Starting job preparation.
# [2021-03-25T21:06:15.469700] Extracting the control code.
# [2021-03-25T21:06:15.507648] fetching and extracting the control code on master node.
# [2021-03-25T21:06:15.507708] Starting extract_project.
# [2021-03-25T21:06:15.507762] Starting to extract zip file.
# [2021-03-25T21:06:16.695034] Finished extracting zip file.
# [2021-03-25T21:06:17.292089] Using urllib.request Python 3.0 or later
# [2021-03-25T21:06:17.292152] Start fetching snapshots.
# [2021-03-25T21:06:17.292189] Start fetching snapshot.
# [2021-03-25T21:06:17.292200] Retrieving project from snapshot: 3be0e252-0ffd-4a35-9277-27b60d8d791d
# Starting the daemon thread to refresh tokens in background for process with pid = 48
# [2021-03-25T21:06:18.224184] Finished fetching snapshot.
# [2021-03-25T21:06:18.224228] Finished fetching snapshots.
# [2021-03-25T21:06:18.224237] Finished extract_project.
# [2021-03-25T21:06:18.237788] Finished fetching and extracting the control code.
# [2021-03-25T21:06:18.241532] downloadDataStore - Download from datastores if requested.
# [2021-03-25T21:06:18.243119] Start run_history_prep.
# [2021-03-25T21:06:18.349633] Entering context manager injector.
# Acquired lockfile /tmp/660aadd3-a519-44d2-8a9f-c65406043a61-datastore.lock to downloading input data references
# [2021-03-25T21:06:18.896833] downloadDataStore completed
# [2021-03-25T21:06:18.900557] Job preparation is complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/03/25 21:06:20 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/03/25 21:06:20 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# [2021-03-25T21:06:22.682211] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['prep_diabetes.py', '--input-data', 'ff8a00da-9ff5-40f5-a399-65a5a6af758c', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/mounts/workspaceblobstore/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/prepped_data_folder'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 103
# [2021-03-25T21:06:25.047458] Entering Run History Context Manager.
# 2021/03/25 21:06:25 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# [2021-03-25T21:06:25.911630] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/mounts/workspaceblobstore/azureml/660aadd3-a519-44d2-8a9f-c65406043a61
# [2021-03-25T21:06:25.912160] Preparing to call script [prep_diabetes.py] with arguments:['--input-data', 'ff8a00da-9ff5-40f5-a399-65a5a6af758c', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/mounts/workspaceblobstore/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/prepped_data_folder']
# [2021-03-25T21:06:25.912219] After variable expansion, calling script [prep_diabetes.py] with arguments:['--input-data', 'ff8a00da-9ff5-40f5-a399-65a5a6af758c', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/mounts/workspaceblobstore/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/prepped_data_folder']
#
# Loading Data...
# Saving Data...
# Starting the daemon thread to refresh tokens in background for process with pid = 103
#
#
# [2021-03-25T21:06:41.803963] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.12041544914245605 seconds
# [2021-03-25T21:06:42.306937] Finished context manager injector.
# Streaming azureml-logs/75_job_post-tvmps_579d96b9128ed68ee9a6c995d54cbdb3636f100cf7f6164381a55108db23da7a_d.txt
# ===============================================================================================================
# [2021-03-25T21:06:49.420819] Entering job release
# [2021-03-25T21:06:50.336160] Starting job release
# [2021-03-25T21:06:50.336844] Logging experiment finalizing status in history service.
# [2021-03-25T21:06:50.337013] job release stage : upload_datastore starting...
# [2021-03-25T21:06:50.337218] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-25T21:06:50.337316] job release stage : execute_job_release starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 338
# [2021-03-25T21:06:50.337805] job release stage : copy_batchai_cached_logs starting...
# [2021-03-25T21:06:50.337911] job release stage : copy_batchai_cached_logs completed...
# [2021-03-25T21:06:50.340623] Entering context manager injector.
# [2021-03-25T21:06:50.623065] job release stage : upload_datastore completed...
# ...
# >>>   2021/03/25 21:07:24 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/azureml_compute_logs/65_job_prep-tvmps_579d96b9128ed68ee9a6c995d54cbdb3636f100cf7f6164381a55108db23da7a_d.txt
# >>>   2021/03/25 21:07:24 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/ce7a06f8-0dc4-47d3-a27f-c9da2a1b52d9/job-1/cb2cab13-d99b-42da-b_e3a6cabd-96f5-4287-8e99-a36162e3ac87/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643;/azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin/python /mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"3be0e252-0ffd-4a35-9277-27b60d8d791d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/03/25 21:07:24 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/03/25 21:07:24 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-b0d93db3d781e376794f1cd37929e45d-45164011a284e13f-01 -t cb2cab13-d99b-42da-bc69-0d634aca4643 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/ce7a06f8-0dc4-47d3-a27f-c9da2a1b52d9/job-1/cb2cab13-d99b-42da-b_e3a6cabd-96f5-4287-8e99-a36162e3ac87/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643;/azureml-envs/azureml_47db242d52dc78151f1bb8d6d04d435d/bin/python /mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"3be0e252-0ffd-4a35-9277-27b60d8d791d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/03/25 21:07:28 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 1
# >>>   FilteredData: 0.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:25.470307] Entering job preparation.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:27.963320] Starting job preparation.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:27.963361] Extracting the control code.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:28.029534] fetching and extracting the control code on master node.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:28.029577] Starting extract_project.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:28.029626] Starting to extract zip file.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:29.533273] Finished extracting zip file.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:29.967413] Using urllib.request Python 3.0 or later
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:29.967471] Start fetching snapshots.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:29.967509] Start fetching snapshot.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:29.967525] Retrieving project from snapshot: 3be0e252-0ffd-4a35-9277-27b60d8d791d
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 49
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:30.423238] Finished fetching snapshot.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:30.423269] Finished fetching snapshots.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:30.423281] Finished extract_project.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:30.582692] Finished fetching and extracting the control code.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:30.587059] downloadDataStore - Download from datastores if requested.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:30.588435] Start run_history_prep.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:30.713263] Entering context manager injector.
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: Acquired lockfile /tmp/cb2cab13-d99b-42da-bc69-0d634aca4643-datastore.lock to downloading input data references
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:31.237236] downloadDataStore completed
# >>>   2021/03/25 21:07:32 runSpecialJobTask: preparation: [2021-03-25T21:07:31.240470] Job preparation is complete.
# >>>   2021/03/25 21:07:32 Execution of runSpecialJobTask completed
# >>>   2021/03/25 21:07:32 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/03/25 21:07:32 Process Exiting with Code:  0
# >>>   2021/03/25 21:07:32 All App Insights Logs was send successfully
# >>>
# 2021-03-25T21:07:32Z 127.0.0.1 slots=2 max-slots=2
# 2021-03-25T21:07:32Z launching Custom job
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/03/25 21:07:33 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/03/25 21:07:33 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# [2021-03-25T21:07:35.069298] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train_diabetes.py', '--training-folder', '/mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/prepped_data_folder'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 105
# [2021-03-25T21:07:38.122521] Entering Run History Context Manager.
# 2021/03/25 21:07:38 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# [2021-03-25T21:07:38.913371] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643
# [2021-03-25T21:07:38.913887] Preparing to call script [train_diabetes.py] with arguments:['--training-folder', '/mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/prepped_data_folder']
# [2021-03-25T21:07:38.913947] After variable expansion, calling script [train_diabetes.py] with arguments:['--training-folder', '/mnt/batch/tasks/shared/LS_root/jobs/azure_ds_challenge/azureml/cb2cab13-d99b-42da-bc69-0d634aca4643/mounts/workspaceblobstore/azureml/660aadd3-a519-44d2-8a9f-c65406043a61/prepped_data_folder']
#
# Loading Data...
# Training a decision tree model...
# Accuracy: 0.8988888888888888
# AUC: 0.8837616052365906
# Saving model...
# Registering model...
# Registering model diabetes_model
# Starting the daemon thread to refresh tokens in background for process with pid = 105
#
#
# [2021-03-25T21:07:49.085592] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.10649442672729492 seconds
# [2021-03-25T21:07:50.023406] Finished context manager injector.
# 2021/03/25 21:07:50 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/03/25 21:07:50 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/03/25 21:07:50 Process Exiting with Code:  0
#
# Streaming azureml-logs/75_job_post-tvmps_579d96b9128ed68ee9a6c995d54cbdb3636f100cf7f6164381a55108db23da7a_d.txt
# ===============================================================================================================
# [2021-03-25T21:07:51.799309] Entering job release
# [2021-03-25T21:07:52.824975] Starting job release
# [2021-03-25T21:07:52.853332] Logging experiment finalizing status in history service.
# [2021-03-25T21:07:52.854020] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 167
# [2021-03-25T21:07:52.854569] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-25T21:07:52.854603] job release stage : execute_job_release starting...
# [2021-03-25T21:07:52.855213] job release stage : copy_batchai_cached_logs starting...
# [2021-03-25T21:07:52.857207] job release stage : copy_batchai_cached_logs completed...
# [2021-03-25T21:07:52.864027] Entering context manager injector.
# [2021-03-25T21:07:53.092562] job release stage : upload_datastore completed...
# [2021-03-25T21:07:53.171953] job release stage : execute_job_release completed...
# [2021-03-25T21:07:53.174199] job release stage : send_run_telemetry starting...
# [2021-03-25T21:07:53.452353] get vm size and vm region successfully.
# [2021-03-25T21:07:53.830297] get compute meta data successfully.
# [2021-03-25T21:07:54.654627] post artifact meta request successfully.
# [2021-03-25T21:07:54.699239] upload compute record artifact successfully.
# [2021-03-25T21:07:54.884174] job release stage : send_run_telemetry completed...
# [2021-03-25T21:07:54.884654] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': 'cb2cab13-d99b-42da-bc69-0d634aca4643', 'target': 'azure-compute', 'status': 'Completed', 'startTimeUtc': '2021-03-25T21:07:19.541226Z', 'endTimeUtc': '2021-03-25T21:08:03.903588Z', 'properties': {'ContentSnapshotId': '3be0e252-0ffd-4a35-9277-27b60d8d791d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'ba35d0db-be3b-4f08-807d-56727ab1aa0a', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '8196ca8d', 'azureml.pipelinerunid': '12849b14-2b76-4c57-a609-c605d5e8a9f3', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'azure-compute', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/660aadd3-a519-44d2-8a9f-c65406043a61/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.22.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_47db242d52dc78151f1bb8d6d04d435d'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_579d96b9128ed68ee9a6c995d54cbdb3636f100cf7f6164381a55108db23da7a_d.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.cb2cab13-d99b-42da-bc69-0d634aca4643/azureml-logs/55_azureml-execution-tvmps_579d96b9128ed68ee9a6c995d54cbdb3636f100cf7f6164381a55108db23da7a_d.txt?sv=2019-02-02&sr=b&sig=CXl6NjIDBZfNzFJOPLxZkkE87tIK2B2o3UFlqsV2X%2Fk%3D&st=2021-03-25T20%3A57%3A57Z&se=2021-03-26T05%3A07%3A57Z&sp=r', 'azureml-logs/65_job_prep-tvmps ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '12849b14-2b76-4c57-a609-c605d5e8a9f3', 'status': 'Completed', 'startTimeUtc': '2021-03-25T20:52:02.235324Z', 'endTimeUtc': '2021-03-25T21:08:06.973009Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.12849b14-2b76-4c57-a609-c605d5e8a9f3/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=Y37%2FuB59eGybTLwzTIZcT2tBBP7KOSONZbisZtqQW30%3D&st=2021-03-25T20%3A42%3A05Z&se=2021-03-26T04%3A52%3A05Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.12849b14-2b76-4c57-a609-c605d5e8a9f3/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=fh%2FHshjYcJRErMIANXbS8r%2F8kQJRm3Qr4jlbFbo5sYU%3D&st=2021-03-25T20%3A42%3A05Z&se=2021-03-26T04%3A52%3A05Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.12849b14-2b76-4c57-a609-c605d5e8a9f3/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=DbYxZZqm%2BC7n1VdI%2Bp%2FYysYl1F7lAsojeRtYkbqSZgE%3D&st=2021-03-25T20%3A42%3A05Z&se=2021-03-26T04%3A52%3A05Z&sp=r'}, 'submittedBy': 'Chidi Ndego'}
# 'Finished'

# %% [markdown]
# A graphical representation of the pipeline experiment will be displayed in the widget as it runs. Keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, you can examine the metrics recorded by it's child runs.

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8988888888888888
# 	 AUC : 0.8837616052365906
# 	 ROC : aml://artifactId/ExperimentRun/dcid.cb2cab13-d99b-42da-bc69-0d634aca4643/ROC_1616706461.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 6
# 	 Training context : Pipeline
# 	 AUC : 0.8837616052365906
# 	 Accuracy : 0.8988888888888888
#
#
# diabetes_model version: 5
# 	 Training context : Compute cluster
# 	 AUC : 0.8832499705804543
# 	 Accuracy : 0.8977777777777778
#
#
# diabetes_model version: 4
# 	 Training context : File dataset
# 	 AUC : 0.8568517900798176
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 3
# 	 Training context : Tabular dataset
# 	 AUC : 0.8568595320655352
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized script
# 	 AUC : 0.8484357430717946
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8483203144435048
# 	 Accuracy : 0.774

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: 75fdaca6-3cc5-4f80-aef5-4e854813d5f5,
# Status: Active,
# Endpoint: https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/cdb9c206-0977-4fc2-9190-23ed6c7c7063/resourceGroups/stanbic/providers/Microsoft.MachineLearningServices/workspaces/azure_ds_challenge/PipelineRuns/PipelineSubmit/75fdaca6-3cc5-4f80-aef5-4e854813d5f5)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the **Endpoints** page (on the **Pipeline Endpoints** tab) in [Azure Machine Learning studio](https://ml.azure.com). You can also find its URI as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/cdb9c206-0977-4fc2-9190-23ed6c7c7063/resourceGroups/stanbic/providers/Microsoft.MachineLearningServices/workspaces/azure_ds_challenge/PipelineRuns/PipelineSubmit/75fdaca6-3cc5-4f80-aef5-4e854813d5f5

# %% [markdown]
# ## Call the pipeline endpoint
#
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# 'f7a69e3b-2ec8-44d4-b469-60f3c2c88019'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this course. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: f7a69e3b-2ec8-44d4-b469-60f3c2c88019
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/f7a69e3b-2ec8-44d4-b469-60f3c2c88019?wsid=/subscriptions/cdb9c206-0977-4fc2-9190-23ed6c7c7063/resourcegroups/stanbic/workspaces/azure_ds_challenge
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'f7a69e3b-2ec8-44d4-b469-60f3c2c88019', 'status': 'Completed', 'startTimeUtc': '2021-03-25T21:09:04.776827Z', 'endTimeUtc': '2021-03-25T21:09:07.292783Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': '75fdaca6-3cc5-4f80-aef5-4e854813d5f5'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.f7a69e3b-2ec8-44d4-b469-60f3c2c88019/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=JLeplJ%2BJNDMQ1yHSuH7MlYQLFznL6bUPy8qywTKw9Ro%3D&st=2021-03-25T20%3A59%3A11Z&se=2021-03-26T05%3A09%3A11Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.f7a69e3b-2ec8-44d4-b469-60f3c2c88019/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=6w9sx8d0OJfBuNhRukhl85CJ%2FYyEEsWQ0He65abYJxM%3D&st=2021-03-25T20%3A59%3A11Z&se=2021-03-26T05%3A09%3A11Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.f7a69e3b-2ec8-44d4-b469-60f3c2c88019/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=%2BOH9OaHVMvyXNlfslIodqzVGaLkUmIpG%2FDtBlxqAo5E%3D&st=2021-03-25T20%3A59%3A11Z&se=2021-03-26T05%3A09%3A11Z&sp=r'}, 'submittedBy': 'Chidi Ndego'}
# 'Finished'

# %% [markdown]
# ## Schedule the Pipeline
#
# Suppose the clinic for the diabetes patients collects new data each week, and adds it to the dataset. You could run the pipeline every week to retrain the model with the new data.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# Submit the Pipeline every Monday at 00:00 UTC
recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
                                  description="Based on time",
                                  pipeline_id=published_pipeline.id, 
                                  experiment_name='mslearn-diabetes-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')
# Out:
# Pipeline scheduled.

# %% [markdown]
# You can retrieve the schedules that are defined in the workspace like this:

# %%
schedules = Schedule.list(ws)
schedules
# Out:
# [Pipeline(Name: weekly-diabetes-training,
#  Id: 5e43aa2d-6902-4a54-b55d-791f81c9e8eb,
#  Status: Active,
#  Pipeline Id: 75fdaca6-3cc5-4f80-aef5-4e854813d5f5,
#  Pipeline Endpoint Id: None,
#  Recurrence Details: Runs at 0:00 on Monday every Week)]

# %% [markdown]
# You can check the latest run like this:

# %%
pipeline_experiment = ws.experiments.get('mslearn-diabetes-pipeline')
latest_run = list(pipeline_experiment.get_runs())[0]

latest_run.get_details()
# Out:
# {'runId': '59febbe2-ece1-472e-8499-5ce29ebcc34f',
#  'status': 'Completed',
#  'startTimeUtc': '2021-03-25T21:09:23.263152Z',
#  'endTimeUtc': '2021-03-25T21:09:25.213027Z',
#  'properties': {'azureml.git.repository_uri': 'https://github.com/MicrosoftLearning/mslearn-dp100',
#   'mlflow.source.git.repoURL': 'https://github.com/MicrosoftLearning/mslearn-dp100',
#   'azureml.git.branch': 'main',
#   'mlflow.source.git.branch': 'main',
#   'azureml.git.commit': 'f239fd89deb74b8808e79f452dab1b737a3c3070',
#   'mlflow.source.git.commit': 'f239fd89deb74b8808e79f452dab1b737a3c3070',
#   'azureml.git.dirty': 'True',
#   'azureml.runsource': 'azureml.PipelineRun',
#   'runSource': 'Unavailable',
#   'runType': 'Schedule',
#   'azureml.parameters': '{}',
#   'azureml.pipelineid': '75fdaca6-3cc5-4f80-aef5-4e854813d5f5'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'logs/azureml/executionlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.59febbe2-ece1-472e-8499-5ce29ebcc34f/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=9YJCduhmhWDzmQb6GevHvUVmk39SkN9ULQ50o0fY5kQ%3D&st=2021-03-25T20%3A59%3A30Z&se=2021-03-26T05%3A09%3A30Z&sp=r',
#   'logs/azureml/stderrlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.59febbe2-ece1-472e-8499-5ce29ebcc34f/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=udwsV0fJm%2FyZrRcC8WtE4jgM%2F7ftZ0snogyhd4CjHag%3D&st=2021-03-25T20%3A59%3A30Z&se=2021-03-26T05%3A09%3A30Z&sp=r',
#   'logs/azureml/stdoutlogs.txt': 'https://azuredschallen0050415378.blob.core.windows.net/azureml/ExperimentRun/dcid.59febbe2-ece1-472e-8499-5ce29ebcc34f/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=ZZIps19WUOafzvdKl5h3vx7FFNxTG9W1ehh2A7ZbgF8%3D&st=2021-03-25T20%3A59%3A30Z&se=2021-03-26T05%3A09%3A30Z&sp=r'},
#  'submittedBy': 'Chidi Ndego'}

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
